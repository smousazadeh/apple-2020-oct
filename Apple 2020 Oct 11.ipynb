# %%
print('hello, world!')  # shift + enter
# Out:
# hello, world!

# %%
# REPL -- read, eval, print loop

# %%
# Jupyter

# %%
s = 'abcde'

# %%
print('hello')                    # enter == go down one line
print('hello again')              # enter == go down one line
print('this is getting boring!!!')   # shift + enter == execute the cell
# Out:
# hello
# hello again
# this is getting boring!!!

# %%
s = 'abcde'

# %%
print('hello')                    # enter == go down one line
print('hello again')              # enter == go down one line
print('this is getting boring!!!')   # shift + enter == execute the cell
# Out:
# hello
# hello again
# this is getting boring!!!

# %%
print('hello')                    # enter == go down one line
print('hello again')              # enter == go down one line
print('this is getting boring!!!')   # shift + enter == execute the cell
# Out:
# hello
# hello again
# this is getting boring!!!

# %%
s = 'abcde'

# %%
print('hello')                    # enter == go down one line
print('hello again')              # enter == go down one line
print('this is getting boring!!!')   # shift + enter == execute the cell
# Out:
# hello
# hello again
# this is getting boring!!!

# %%
# a -- add new cell above
# b -- add new cell below

# %%
x = 100
print(x*2)
# Out:
# 200

# %%
x*2
# Out:
# 200

# %%
In
# Out:
# ['',
#  "print('hello, world!')",
#  '# REPL -- read, eval, print loop',
#  '# Jupyter ',
#  "print('hello')                    # enter == go down one line\nprint('hello again')              # enter == go down one line\nprint('this is getting boring')   # shift + enter == execute the cell",
#  "print('hello')                    # enter == go down one line\nprint('hello again')              # enter == go down one line\nprint('this is getting boring!!!')   # shift + enter == execute the cell",
#  'x = 100\nprint(x*2)',
#  'x*2',
#  'In']

# %%
Out
# Out:
# {7: 200,
#  8: ['',
#   "print('hello, world!')",
#   '# REPL -- read, eval, print loop',
#   '# Jupyter ',
#   "print('hello')                    # enter == go down one line\nprint('hello again')              # enter == go down one line\nprint('this is getting boring')   # shift + enter == execute the cell",
#   "print('hello')                    # enter == go down one line\nprint('hello again')              # enter == go down one line\nprint('this is getting boring!!!')   # shift + enter == execute the cell",
#   'x = 100\nprint(x*2)',
#   'x*2',
#   'In',
#   'Out']}

# %%
Out[7]
# Out:
# 200

# %%
10+10
20+20
30+30
# Out:
# 60

# %%
x
# Out:
# 100

# %%
len(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-a7f4a5366567> in <module>
# ----> 1 len(x)
#
# TypeError: object of type 'int' has no len()

# %%
str(x)
# Out:
# '100'

# %%
x = None

# %%
type(x)
# Out:
# NoneType

# %%
y = type(x)()
y

# %%
print(y)
# Out:
# None

# %%
x = None

if x == None:
    print('Yes, it is None!')
else:
    print('No, it is not None!')
# Out:
# Yes, it is None!

# %%
x = None

if x is None:
    print('Yes, it is None!')
else:
    print('No, it is not None!')
# Out:
# Yes, it is None!

# %%
mylist = [10, 20, 30]
other_list = [10, 20, 30]

mylist == other_list
# Out:
# True

# %%
mylist is other_list
# Out:
# False

# %%
id(mylist)
# Out:
# 4411757760

# %%
hex(id(mylist))
# Out:
# '0x106f614c0'

# %%
id(other_list)
# Out:
# 4413890880

# %%
hex(id(other_list))
# Out:
# '0x10716a140'

# %%
# a is b  ==     id(a) == id(b)

# %%
x is None
# Out:
# True

# %%
x = 100
y = 100

x == y
# Out:
# True

# %%
x is y
# Out:
# True

# %%
x = 1000
y = 1000

x == y
# Out:
# True

# %%
x is y
# Out:
# False

# %%
x = None

if x:
    print('None is True-ish')
else:
    print('None is False-ish')
# Out:
# None is False-ish

# %%
None == False
# Out:
# False

# %% [markdown]
# # Everything is `True` in Python's boolean context, except:
#
# - `None`
# - `False`
# - 0
# - Anything empty (`''`, `[]`, `()`, `{}`)

# %%
name = input("Enter your name: ")

if name:
    print(f'Hi, {name}!')
else:
    print(f'Hey, you did not enter a name!')
# Out:
# Enter your name:
# Hey, you did not enter a name!

# %%
x = 1234
type(x)
# Out:
# int

# %%
x = x ** 100
x
# Out:
# 

# %%
x **= 100
x
# Out:
# ...

# %%
x **= 100

# %%
import sys
x = 0
sys.getsizeof(x)
# Out:
# 24

# %%
x = 12345
sys.getsizeof(x)
# Out:
# 28

# %%
x **= 100
sys.getsizeof(x)
# Out:
# 208

# %%
x **= 100
sys.getsizeof(x)
# Out:
# 18148

# %%
s = '12345'

int(s)
# Out:
# 12345

# %%
s
# Out:
# '12345'

# %%
s = '12345'  # oops, it's a hex number!

int(s, 16)  # interpret as a hex number
# Out:
# 74565

# %%
int('123abc', 16)
# Out:
# 1194684

# %%
x = 1
type(x)
# Out:
# int

# %%
x = 1.0
type(x)
# Out:
# float

# %%
0.1 + 0.2
# Out:
# 0.30000000000000004

# %%
print(0.1 + 0.2)
# Out:
# 0.30000000000000004

# %%
round(0.1 + 0.2, 2)
# Out:
# 0.3

# %%
# BCD -- binary coded decimals
from decimal import Decimal 
    
x = Decimal('0.1')
y = Decimal('0.2')

# %%
float(x + y)
# Out:
# 0.3

# %%
x = Decimal(0.1)
y = Decimal(0.2)

# %%
x
# Out:
# Decimal('0.1000000000000000055511151231257827021181583404541015625')

# %%
y
# Out:
# Decimal('0.200000000000000011102230246251565404236316680908203125')

# %%
0.1 + 0.2 == 0.3
# Out:
# False

# %%
0.3 - (0.1 + 0.2) > 0.0000000000000000000000000000000000001
# Out:
# False

# %%
0.1 + 0.2
# Out:
# 0.30000000000000004

# %%
(0.1 + 0.2)  - 0.3 < 0.000000000000000000000000000001
# Out:
# False

# %%
s = 'abcd'
len(s)
# Out:
# 4

# %%
s = 'שלום'
len(s)
# Out:
# 4

# %%
s.encode()
# Out:
# b'\xd7\xa9\xd7\x9c\xd7\x95\xd7\x9d'

# %%
s = '北京'
len(s)
# Out:
# 2

# %%
s.encode()
# Out:
# b'\xe5\x8c\x97\xe4\xba\xac'

# %%
b = s.encode()

# %%
b
# Out:
# b'\xe5\x8c\x97\xe4\xba\xac'

# %%
b[0]
# Out:
# 229

# %%
b[1]
# Out:
# 140

# %%
b.decode()  # give me a string based on these bytes
# Out:
# '北京'

# %%
# Python 2:
#   - strings had bytes
#   - Unicode strings had characters

# Python 3:
#   - strings use characters
#   - byte strings use bytes

# %%
s = 'abcde'
t = 'abcde'

s == t
# Out:
# True

# %%
s is t
# Out:
# True

# %%
s = 'abc.de'
t = 'abc.de'

s == t
# Out:
# True

# %%
s is t
# Out:
# False

# %%
# interning == cache for strings

# %%
s = 'abcde'
t = 'abcde'

id(s)
# Out:
# 4411598768

# %%
id(t)
# Out:
# 4411598768

# %%
s = 'abc.de'
t = 'abc.de'

id(s)
# Out:
# 4409902704

# %%
id(t)
# Out:
# 4409901232

# %%
x = sys.intern('hello!')
y = sys.intern('hello!')

# %%
x is y
# Out:
# True

# %%
s = 'abcd'
